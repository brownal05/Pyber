# %%
# %matplotlib inline
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import matplotlib.cm as cm

# File to Load (Remember to change these)
city_data_to_load = ("data/city_data.csv")
ride_data_to_load =("data/ride_data.csv")

# Read the City and Ride Data
city_df = pd.read_csv(city_data_to_load) 
ride_df = pd.read_csv(ride_data_to_load)
# Combine the data into a single dataset
city_df = city_df.drop_duplicates("city", keep = "first")

merged_df = pd.merge(ride_df, city_df, on = 'city')


# Display the data table for preview

# %%
merged_data.head()
# Out:
#                  city                 date   fare        ride_id  \
# 0  Lake Jonathanshire  2018-01-14 10:14:22  13.83  5739410935873
# 1  Lake Jonathanshire  2018-04-07 20:51:11  31.25  4441251834598
# 2  Lake Jonathanshire  2018-03-09 23:45:55  19.89  2389495660448
# 3  Lake Jonathanshire  2018-04-07 18:09:21  24.28  7796805191168
# 4  Lake Jonathanshire  2018-01-02 14:14:50  13.89   424254840012
#
#    driver_count   type
# 0             5  Urban
# 1             5  Urban
# 2             5  Urban
# 3             5  Urban
# 4             5  Urban

# %% [markdown]
# ## Bubble Plot of Ride Sharing Data

# %%
# Obtain the x and y coordinates for each of the three city types
city = merged_df.groupby("city") 
avg_fare = city.mean()["fare"]
ride_count = city.count()["ride_id"]
driver_count = city.mean()["driver_count"]
#print(driver_count)
# Build the scatter plots for each city types
plt.scatter(ride_count, avg_fare,  color= ["yellow", "blue", "orange"], edgecolors="black",
            s=driver_count, alpha=0.6)
plt.grid()
plt.xlabel("Total Number of Rides (Per City)")
plt.ylabel("Average Fare ($)")
plt.legend(loc = "best", scatterpoints ="int")
# Incorporate the other graph properties

# Create a legend

# Incorporate a text label regarding circle size

# Save Figure
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-59-34577e12c252> in <module>()
#      11 plt.xlabel("Total Number of Rides (Per City)")
#      12 plt.ylabel("Average Fare ($)")
# ---> 13 plt.legend(loc = "best", scatterpoints ="int")
#      14 # Incorporate the other graph properties
#      15
#
# C:\Program Files (x86)\Microsoft Visual Studio\Shared\Anaconda3_64\lib\site-packages\matplotlib\pyplot.py in legend(*args, **kwargs)
#    3816 @docstring.copy_dedent(Axes.legend)
#    3817 def legend(*args, **kwargs):
# -> 3818     ret = gca().legend(*args, **kwargs)
#    3819     return ret
#    3820
#
# C:\Program Files (x86)\Microsoft Visual Studio\Shared\Anaconda3_64\lib\site-packages\matplotlib\axes\_axes.py in legend(self, *args, **kwargs)
#     555         if len(extra_args):
#     556             raise TypeError('legend only accepts two non-keyword arguments')
# ...

# %%
# Show plot
plt.show()

# %% [markdown]
# ## Total Fares by City Type

# %%
# Calculate Type Percents

# Build Pie Chart

# Save Figure

# %%
# Show Figure
plt.show()

# %% [markdown]
# ## Total Rides by City Type

# %%
# Calculate Ride Percents

# Build Pie Chart

# Save Figure

# %%
# Show Figure
plt.show()

# %% [markdown]
# ## Total Drivers by City Type

# %%
# Calculate Driver Percents

# Build Pie Charts

# Save Figure

# %%
# Show Figure
plt.show()
